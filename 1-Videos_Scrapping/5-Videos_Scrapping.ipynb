# %%
import csv
import requests
from bs4 import BeautifulSoup

# %%
url='https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-006-introduction-to-algorithms-spring-2020/lecture-videos/#'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="/static_shared/css/course_v2.9f665.css" rel="stylesheet"/>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NMQZ25T');</script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
# <meta content="MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity" name="description"/>
# <meta content="opencourseware,MIT OCW,courseware,MIT opencourseware,Free Courses,class notes,class syllabus,class materials,tutorials,online courses,MIT courses" name="keywords"/>
# ...

# %%
nav = soup.find('div', attrs={'id': 'nav-container_mobile_7d2ea4af-b24a-df20-2423-9a0889bc50ab'})
nav
# Out:
# <div class="collapse" id="nav-container_mobile_7d2ea4af-b24a-df20-2423-9a0889bc50ab">
# <ul class="course-nav-child-nav m-auto">
# </ul>
# </div>

# %%
find_a=soup.find_all('a')
find_a_text=[]
for i in range(len(find_a)-1,-1,-1):
    find_a_text.append(find_a[i].get_text())
find_a_text
# Out:
# ['\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  'Terms and Conditions',
#  'Creative Commons License',
#  'Accessibility',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  'Learn more',
#  '\n\n',
#  '\nDownload Course\n',
#  'Computation',
#  'Mathematics',
#  '\n\n',
#  'Theory of Computation',
#  'Algorithms and Data Structures',
#  'Computer Science',
#  '\n\n',
#  'Engineering',
#  '\n\n',
#  'Undergraduate',
#  'Electrical Engineering and Computer Science',
#  'Prof. Justin Solomon',
#  'Dr. Jason Ku',
#  'Prof. Erik Demaine',
#  'Lecture 21: Algorithmsâ\x80\x94Next Steps',
#  '\n\n',
#  'Lecture 20: Course Review',
#  '\n\n',
#  'Lecture 19: Complexity',
#  '\n\n',
#  'Lecture 18: Dynamic Programming, Part 4: Rods, Subset Sum, Pseudopolynomial',
#  '\n\n',
#  'Lecture 17: Dynamic Programming, Part 3: APSP, Parens, Piano',
#  '\n\n',
#  'Lecture 16: Dynamic Programming, Part 2: LCS, LIS, Coins',
#  '\n\n',
# ...

# %%
file_name = soup.find('title').get_text().split(' | ')[1]
file_name += '.csv'
file_name
# Out:
# 'Introduction to Algorithms.csv'

# %%
with open(file_name, mode='w', encoding='utf-8') as csv_file:
    fieldnames = ['video_name', 'video_url']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for a in soup.find_all('a', attrs={'class': 'bullet medialink'}):
        video_name = a.get_text()
        video_url = 'https://ocw.mit.edu' + a.get('href')
        writer.writerow({'video_name': video_name, 'video_url': video_url})

# %%
import pandas as pd

# %%
data = pd.read_csv(file_name)
data
# Out:
#                                            video_name  \
# 0               Lecture 1: Algorithms and Computation
# 1       Lecture 2: Data Structures and Dynamic Arrays
# 2                                   Problem Session 1
# 3                         Lecture 3: Sets and Sorting
# 4                                  Lecture 4: Hashing
# 5                                   Problem Session 2
# 6                           Lecture 5: Linear Sorting
# 7                                   Problem Session 3
# 8                     Lecture 6: Binary Trees, Part 1
# 9                Lecture 7: Binary Trees, Part 2: AVL
# 10                                  Problem Session 4
# 11                            Lecture 8: Binary Heaps
# 12                    Lecture 9: Breadth-First Search
# 13                                      Quiz 1 Review
# 14                     Lecture 10: Depth-First Search
# 15                Lecture 11: Weighted Shortest Paths
# ...
